# %%
import pandas as pd
import requests
import json

# %%
# response=requests.get("https://imdb.iamidiotareyoutoo.com/search?q=mark")

# %%
# response.json()

# %%
response = requests.get('https://newsapi.org/v2/everything?q=tesla&from=2026-05-26&sortBy=publishedAt&apiKey=4ae06953631d446187a2c9a796db97ea')

# %%
result=response.json()['articles']

# %%
df=pd.DataFrame(result)

# %%
df.shape
# Out:
# (97, 8)

# %%
df.head(1)
# Out:
#                                  source author  \
# 0  {'id': None, 'name': 'Hwupgrade.it'}    NaN
#
#                                                title  \
# 0  Attacco informatico a Tata: rubati dati sui pr...
#
#                                          description  \
# 0  Tata Electronics ha subito un attacco informat...
#
#                                                  url  \
# 0  https://www.hwupgrade.it/news/web/attacco-info...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.hwupgrade.it/i/n/Apple_speseADV_72...  2026-06-25T06:01:01Z
#
#                                              content
# 0  Tata Electronics ha confermato di aver subito ...

# %%
df= df.copy()
df['source'] = df['source'].apply(
    lambda x: x['name'] if isinstance(x, dict) else None
)
df.head()
# Out:
#             source        author  \
# 0     Hwupgrade.it           NaN
# 1  Naturalnews.com  Jacob Thomas
# 2       Prtimes.jp           NaN
# 3         Ixbt.com           Jin
# 4         Ixbt.com           Jin
#
#                                                title  \
# 0  Attacco informatico a Tata: rubati dati sui pr...
# 1  Scientists confirm: Sodium-ion batteries could...
# 2                                    世界で最もテスラが安い街、東京
# 3  Телепатия станет реальностью? Маск заявил, что...
# 4  Tesla и GIGA Storage готовят гигантскую батаре...
#
#                                          description  \
# 0  Tata Electronics ha subito un attacco informat...
# 1  A study in Cell Reports Physical Science confi...
# 2  [Tesla Japan 合同会社]\n[画像1: https://prcdn.freetl...
# 3        Идея предполагает общение без слов и жестов
# 4  Новая система накопления энергии станет одним ...
#
#                                                  url  \
# 0  https://www.hwupgrade.it/news/web/attacco-info...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   source       97 non-null     str
#  1   author       88 non-null     str
#  2   title        97 non-null     str
#  3   description  97 non-null     str
#  4   url          97 non-null     str
#  5   urlToImage   92 non-null     str
#  6   publishedAt  97 non-null     str
#  7   content      97 non-null     str
# dtypes: str(8)
# memory usage: 78.2 KB

# %%
df.drop(columns=['description','content'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   source       97 non-null     str
#  1   author       88 non-null     str
#  2   title        97 non-null     str
#  3   url          97 non-null     str
#  4   urlToImage   92 non-null     str
#  5   publishedAt  97 non-null     str
# dtypes: str(6)
# memory usage: 36.3 KB

# %%
df.rename(columns={'source':'sourceName','author':'authorName','url':'sourceUrl','urlToImage':'PostUrl','publishedAt':'publishedDate'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sourceName     97 non-null     str
#  1   authorName     88 non-null     str
#  2   title          97 non-null     str
#  3   sourceUrl      97 non-null     str
#  4   PostUrl        92 non-null     str
#  5   publishedDate  97 non-null     str
# dtypes: str(6)
# memory usage: 36.3 KB

# %%
df.to_csv('News.csv',index=False)
