# %%
api='https://www.themealdb.com/api/json/v1/1/list.php?i=list'

# %%
import pandas as pd
import requests

# %%
response=requests.get(api)

# %%
data=response.json()

# %%
df=pd.DataFrame(data['meals'])

# %%
df
# Out:
#     idIngredient     strIngredient  \
# 0              1           Chicken
# 1              2            Salmon
# 2              3              Beef
# 3              4              Pork
# 4              5           Avocado
# ..           ...               ...
# 926          965     Banana Leaves
# 927          966     Pigs Trotters
# 928          967  Red Pepper Sauce
# 929          968   Evaporated Milk
# 930          969      Ground Onion
#
#                                         strDescription  \
# 0    The chicken is a type of domesticated fowl, a ...
# 1    Salmon is the common name for several species ...
# 2    Beef is the culinary name for meat from cattle...
# 3    Pork is the culinary name for the flesh of a d...
# 4    The avocado, a tree with probable origin in So...
# ..                                                 ...
# 926  Banana leaves are the large, flexible, and wat...
# 927  Pig trotters, also known as pig's feet or pett...
# 928  Red pepper sauce is a versatile, vibrant condi...
# 929  Evaporated milk is a shelf-stable, canned dair...
# 930  Ground onion generally refers to a dried, powd...
#
#                                               strThumb    strType
# 0    https://www.themealdb.com/images/ingredients/c...        NaN
# 1    https://www.themealdb.com/images/ingredients/s...        NaN
# 2    https://www.themealdb.com/images/ingredients/b...        NaN
# 3    https://www.themealdb.com/images/ingredients/p...        NaN
# 4    https://www.themealdb.com/images/ingredients/a...        NaN
# ..                                                 ...        ...
# 926  https://www.themealdb.com/images/ingredients/B...      Fruit
# 927                                                NaN       Meat
# 928                                                NaN   Dressing
# 929                                                NaN      Dairy
# 930                                                NaN  Seasoning
#
# [931 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 931 entries, 0 to 930
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   idIngredient    931 non-null    str
#  1   strIngredient   931 non-null    str
#  2   strDescription  478 non-null    str
#  3   strThumb        908 non-null    str
#  4   strType         446 non-null    str
# dtypes: str(5)
# memory usage: 502.1 KB

# %%
df.to_csv('Recipe.csv')
