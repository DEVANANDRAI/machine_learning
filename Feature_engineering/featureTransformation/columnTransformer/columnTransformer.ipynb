# %%
from sklearn.compose import ColumnTransformer

transformer = ColumnTransformer(transformers=[
    ('tnf1', SimpleImputer(), ['fever']),
    ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
    ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])
], remainder='passthrough')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.compose import ColumnTransformer
#       3 transformer = ColumnTransformer(transformers=[
# ----> 4     ('tnf1', SimpleImputer(), ['fever']),
#       5     ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
#       6     ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])
#       7 ], remainder='passthrough')
#
# NameError: name 'SimpleImputer' is not defined
