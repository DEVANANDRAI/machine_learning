# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("Package In LPA")
# Out:
# Text(0, 0.5, 'Package In LPA')

# %%
X=df.iloc[:,0:1]
Y=df.iloc[:,-1]
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=12,shuffle=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      cgpa
# 23   6.19
# 182  5.88
# 172  6.93
# 21   6.85
# 63   9.16
# 11   6.61
# 61   5.48
# 32   6.96
# 164  9.06
# 7    6.75
# 95   6.63
# 173  6.75
# 132  5.84
# 120  5.23
# 98   7.69
# 138  7.91
# 31   8.10
# 16   6.84
# 181  8.22
# 85   4.79
# 185  6.31
# 166  8.60
# 101  6.71
# 129  7.29
# 113  6.94
# 51   9.26
# 167  8.13
# 88   4.73
# 108  7.76
# 136  5.64
# 29   7.15
# 183  7.28
# 152  7.37
# 93   6.79
# 189  8.11
# 139  7.19
# 179  7.14
# 55   8.20
# 1    5.12
# 5    7.89

# %%
y_test
# Out:
# 23     2.48
# 182    2.08
# 172    2.51
# 21     2.93
# 63     4.25
# 11     2.60
# 61     1.61
# 32     3.08
# 164    3.82
# 7      2.48
# 95     2.79
# 173    2.56
# 132    2.48
# 120    1.73
# 98     3.83
# 138    3.89
# 31     3.89
# 16     2.35
# 181    3.89
# 85     1.48
# 185    3.18
# 166    3.98
# 101    3.52
# 129    3.12
# 113    2.37
# 51     3.79
# 167    3.60
# 88     1.48
# 108    3.54
# 136    2.10
# 29     3.49
# 183    2.72
# 152    3.08
# 93     3.08
# 189    4.06
# 139    2.40
# 179    3.03
# 55     3.39
# 1      1.98
# 5      2.99
# Name: package, dtype: float64

# %%
x_test.iloc[0].values.reshape(1,1)
# Out:
# array([[6.19]])

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\tripu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.56594331])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel("CGPA")
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
lr.coef_
# Out:
# array([0.56274021])

# %%
m=lr.coef_

# %%
lr.intercept_
# Out:
# np.float64(-0.9174186091782945)

# %%
b=lr.intercept_

# %%
# y=mx+b

# %%
m*6.87+b
# Out:
# array([2.94860666])

# %%
from sklearn.metrics import r2_score
y_pred = lr.predict(x_test)
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2*100)
# Out:
# R2 Score: 78.1484367210837
