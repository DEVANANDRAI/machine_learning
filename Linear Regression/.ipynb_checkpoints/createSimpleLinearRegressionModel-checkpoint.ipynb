# %%
class SelfLinearRegression:
    def __init__(self):
        self.m=0
        self.b=0
    def fit(self,x_train,y_train):
        numerator=0
        denominator=0
        prin(len(x_train))
        for i in range(x_train):
            numerator=numerator+(x_train[i]-x_train.mean())*(y_train[i]-y_train.mean())
            denominator=denominator+(x_train[i]-x_train.mean())**2
            self.m=numerator/demoninator
            self.b=(y_train.mean()-(self.m*x_train.mean()))
        
    def predict(self,x_test):
        return self.b+self.m*x_test

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df['cgpa']
y=df['package']
# y.values
y.shape
x[0]
# Out:
# np.float64(6.89)

# %%
lr=SelfLinearRegression()

# %% [raw]
# lr.fit(x)

# %%
lr.predict(6.89)
# Out:
# 0.0
