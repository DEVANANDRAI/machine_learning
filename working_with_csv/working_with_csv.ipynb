# %% [markdown]
# # *IMPORTING PANDAS*

# %%
import pandas as pd

# %% [markdown]
# # *<b style="color:'aqua' background-color:'red'">Opening a local csv file</b>*

# %%
df=pd.read_csv("flights_tickets_serp2020-04-01.csv")
df
# Out:
#                searchTerms  rank  \
# 0     flights to hong kong     1
# 1     flights to hong kong     2
# 2     flights to hong kong     3
# 3     flights to hong kong     4
# 4     flights to hong kong     5
# ...                    ...   ...
# 3995       tickets to nice     6
# 3996       tickets to nice     7
# 3997       tickets to nice     8
# 3998       tickets to nice     9
# 3999       tickets to nice    10
#
#                                                   title  \
# 0     $103 Flights to Hong Kong, China (HKG) - Tripa...
# 1           Flights to Hong Kong (HKG) | Cathay Pacific
# 2     Cheap Flights to Hong Kong SAR, Asia (HKG Airp...
# 3     Cheap Flights to Hong Kong (HKG) from $487 - K...
# 4     $404 Cheap Flights to Hong Kong Intl in 2020 |...
# ...                                                 ...
# 3995                          OGC Nice official website
# 3996  Options for buying train tickets in Nice - Nic...
# ...

# %% [markdown]
# <h1 style="color:red; background:aqua'">Opening a csv file from an Url</h1>

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"
}

req = requests.get(url, headers=headers)
data = StringIO(req.text)

df = pd.read_csv(data)
df
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Sep Parameter

# %%
df1=pd.read_csv("titanic.tsv")
df1
# Out:
#          1\t0\t3\tBraund  \
# 0       2\t1\t1\tCumings
# 1     3\t1\t3\tHeikkinen
# 2      4\t1\t1\tFutrelle
# 3         5\t0\t3\tAllen
# 4         6\t0\t3\tMoran
# ..                   ...
# 885  887\t0\t2\tMontvila
# 886    888\t1\t1\tGraham
# 887  889\t0\t3\tJohnston
# 888      890\t1\t1\tBehr
# 889    891\t0\t3\tDooley
#
#      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7.25\t\N\tS
# 0     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 1     Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 2     Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 3     Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# 4     Mr. James\tmale\t\N\t0\t0\t330877\t8.4583\t\N\tQ
# ..                                                 ...
# 885     Rev. Juozas\tmale\t27\t0\t0\t211536\t13\t\N\tS
# 886   Miss. Margaret Edith\tfemale\t19\t0\t0\t11205...
# 887   Miss. Catherine Helen "Carrie"\tfemale\t\N\t1...
# 888   Mr. Karl Howell\tmale\t26\t0\t0\t111369\t30\t...
# ...

# %%
df2=pd.read_csv("titanic.tsv",sep="\t")# sep="\t" is used because data is separated by the tab by default sep valued is set as comma
df2 # Here is no name for columns. So use names parameter
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  22  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38
# 1      3  1  3                             Heikkinen, Miss. Laina  female  26
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35
# 3      5  0  3                           Allen, Mr. William Henry    male  35
# 4      6  0  3                                   Moran, Mr. James    male  \N
# ..   ... .. ..                                                ...     ...  ..
# 885  887  0  2                              Montvila, Rev. Juozas    male  27
# 886  888  1  1                       Graham, Miss. Margaret Edith  female  19
# 887  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female  \N
# 888  890  1  1                              Behr, Mr. Karl Howell    male  26
# 889  891  0  3                                Dooley, Mr. Patrick    male  32
#
# ...

# %% [markdown]
# ## Name parameter

# %%
df2=pd.read_csv("titanic.tsv",sep="\t",names=['Sr.No.','Val1','Val2','Name','Gender',"Age","Val3","Val4","Address","Street No.","Counting","Marks"])

# %%
df2
# Out:
#      Sr.No.  Val1  Val2                                               Name  \
# 0         1     0     3                            Braund, Mr. Owen Harris
# 1         2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3     1     3                             Heikkinen, Miss. Laina
# 3         4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         5     0     3                           Allen, Mr. William Henry
# ..      ...   ...   ...                                                ...
# 886     887     0     2                              Montvila, Rev. Juozas
# 887     888     1     1                       Graham, Miss. Margaret Edith
# 888     889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889     890     1     1                              Behr, Mr. Karl Howell
# 890     891     0     3                                Dooley, Mr. Patrick
#
# ...

# %%
pd.read_csv("flights_tickets_serp2019-01-15.csv")
# Out:
#                searchTerms  rank  \
# 0     flights to hong kong     1
# 1     flights to hong kong     2
# 2     flights to hong kong     3
# 3     flights to hong kong     4
# 4     flights to hong kong     5
# ...                    ...   ...
# 3995       tickets to nice     6
# 3996       tickets to nice     7
# 3997       tickets to nice     8
# 3998       tickets to nice     9
# 3999       tickets to nice    10
#
#                                                   title  \
# 0     Cheap Flights to Hong Kong (HKG) from $384 - K...
# 1     $506 Flights to Hong Kong, China (HKG) - TripA...
# 2           Flights to Hong Kong (HKG) | Cathay Pacific
# 3     Cheap Flights to Hong Kong International from ...
# 4     Cheap Flights to Hong Kong SAR, Asia $161 in 2...
# ...                                                 ...
# 3995  Cheap Flights to Nice from £20 - Cheapflights....
# 3996                    Billetterie Officielle OGC Nice
# ...

# %% [markdown]
# # Index_col Parameter

# %%
pd.read_csv("flights_tickets_serp2019-01-15.csv",index_col="searchTerms")
# Out:
#                       rank                                              title  \
# searchTerms
# flights to hong kong     1  Cheap Flights to Hong Kong (HKG) from $384 - K...
# flights to hong kong     2  $506 Flights to Hong Kong, China (HKG) - TripA...
# flights to hong kong     3        Flights to Hong Kong (HKG) | Cathay Pacific
# flights to hong kong     4  Cheap Flights to Hong Kong International from ...
# flights to hong kong     5  Cheap Flights to Hong Kong SAR, Asia $161 in 2...
# ...                    ...                                                ...
# tickets to nice          6  Cheap Flights to Nice from £20 - Cheapflights....
# tickets to nice          7                    Billetterie Officielle OGC Nice
# tickets to nice          8  Cheap flights to Nice from £15 - Book trips to...
# tickets to nice          9  OGC Nice Tickets | Buy or Sell Tickets for OGC...
# tickets to nice         10   5 Cheap Flights to Nice @ £41 2018 - TripAdvisor
#
# ...

# %% [markdown]
# # Header Parameter

# %%
pd.read_csv("flights_tickets_serp2019-01-15.csv")
# Out:
#                searchTerms  rank  \
# 0     flights to hong kong     1
# 1     flights to hong kong     2
# 2     flights to hong kong     3
# 3     flights to hong kong     4
# 4     flights to hong kong     5
# ...                    ...   ...
# 3995       tickets to nice     6
# 3996       tickets to nice     7
# 3997       tickets to nice     8
# 3998       tickets to nice     9
# 3999       tickets to nice    10
#
#                                                   title  \
# 0     Cheap Flights to Hong Kong (HKG) from $384 - K...
# 1     $506 Flights to Hong Kong, China (HKG) - TripA...
# 2           Flights to Hong Kong (HKG) | Cathay Pacific
# 3     Cheap Flights to Hong Kong International from ...
# 4     Cheap Flights to Hong Kong SAR, Asia $161 in 2...
# ...                                                 ...
# 3995  Cheap Flights to Nice from £20 - Cheapflights....
# 3996                    Billetterie Officielle OGC Nice
# ...

# %%
pd.read_csv("flights_tickets_serp2019-01-15.csv",header=0)#Header=0 is define the starting point of your rows
# Out:
#                searchTerms  rank  \
# 0     flights to hong kong     1
# 1     flights to hong kong     2
# 2     flights to hong kong     3
# 3     flights to hong kong     4
# 4     flights to hong kong     5
# ...                    ...   ...
# 3995       tickets to nice     6
# 3996       tickets to nice     7
# 3997       tickets to nice     8
# 3998       tickets to nice     9
# 3999       tickets to nice    10
#
#                                                   title  \
# 0     Cheap Flights to Hong Kong (HKG) from $384 - K...
# 1     $506 Flights to Hong Kong, China (HKG) - TripA...
# 2           Flights to Hong Kong (HKG) | Cathay Pacific
# 3     Cheap Flights to Hong Kong International from ...
# 4     Cheap Flights to Hong Kong SAR, Asia $161 in 2...
# ...                                                 ...
# 3995  Cheap Flights to Nice from £20 - Cheapflights....
# 3996                    Billetterie Officielle OGC Nice
# ...

# %% [markdown]
# # use_cols Parameter

# %%
pd.read_csv("flights_tickets_serp2019-02-01.csv").info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   searchTerms            4000 non-null   str
#  1   rank                   4000 non-null   int64
#  2   title                  4000 non-null   str
#  3   snippet                3999 non-null   str
#  4   displayLink            4000 non-null   str
#  5   link                   4000 non-null   str
#  6   queryTime              4000 non-null   str
#  7   totalResults           4000 non-null   int64
#  8   cacheId                3971 non-null   str
#  9   formattedUrl           4000 non-null   str
#  10  htmlFormattedUrl       4000 non-null   str
#  11  htmlSnippet            3999 non-null   str
#  12  htmlTitle              4000 non-null   str
#  13  kind                   4000 non-null   str
#  14  pagemap                3997 non-null   str
# ...

# %%
pd.read_csv("flights_tickets_serp2019-02-01.csv",usecols=['searchTerms','link','htmlTitle','safe','searchTime'])
# usecols is used to define which columns you want to use in dataframe
# Out:
#                searchTerms                                               link  \
# 0     flights to hong kong  https://www.kayak.com/flight-routes/United-Sta...
# 1     flights to hong kong  https://www.tripadvisor.com/Flights-g294217-Ho...
# 2     flights to hong kong  https://www.cathaypacific.com/destinations/en_...
# 3     flights to hong kong  https://www.skyscanner.com/flights-to/hkg/chea...
# 4     flights to hong kong  https://www.expedia.com/Cheap-Flights-To-Hong-...
# ...                    ...                                                ...
# 3995       tickets to nice                 https://billetterie.ogcnice.com/uk
# 3996       tickets to nice          https://www.opodo.co.uk/flights/nice/NCE/
# 3997       tickets to nice  https://www.viagogo.co.uk/Sports-Tickets/Footb...
# 3998       tickets to nice  https://www.tripadvisor.co.uk/Flights-g187234-...
# 3999       tickets to nice          https://www.klm.com/en-gb/flights-to-nice
#
# ...

# %% [markdown]
# # Squeeze Parameter

# %%
#pd.read_csv("flights_tickets_serp2019-02-01.csv",usecols=['title'],squeeze=True)      # Remove from the pandas new version
df = pd.read_csv("flights_tickets_serp2019-02-01.csv",
                 usecols=['title'])

series = df.squeeze("columns")

# %%
series
# Out:
# 0       Cheap Flights to Hong Kong (HKG) from $400 - K...
# 1       $500 Flights to Hong Kong, China (HKG) - TripA...
# 2             Flights to Hong Kong (HKG) | Cathay Pacific
# 3       Cheap Flights to Hong Kong International from ...
# 4       Cheap Flights to Hong Kong SAR, Asia $165 in 2...
#                               ...
# 3995                      Billetterie Officielle OGC Nice
# 3996    Cheap flights to Nice from £22 - Book trips to...
# 3997    OGC Nice Tickets | Buy or Sell Tickets for OGC...
# 3998    5 Cheap Flights to Nice, France (NCE) @ £26 20...
# 3999    Flights to Nice (NCE) | KLM Nice tickets from ...
# Name: title, Length: 4000, dtype: str

# %% [markdown]
# # skiprows/nrows parameter

# %%
pd.read_csv("flights_tickets_serp2019-02-01.csv").head()
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
# 2  flights to hong kong     3
# 3  flights to hong kong     4
# 4  flights to hong kong     5
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $400 - K...
# 1  $500 Flights to Hong Kong, China (HKG) - TripA...
# 2        Flights to Hong Kong (HKG) | Cathay Pacific
# 3  Cheap Flights to Hong Kong International from ...
# 4  Cheap Flights to Hong Kong SAR, Asia $165 in 2...
#
#                                              snippet            displayLink  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...          www.kayak.com
# 1  Book Cheap Flights to Hong Kong: Search and co...    www.tripadvisor.com
# 2  Find & book great deals on Hong Kong (HKG) Fli...  www.cathaypacific.com
# 3  Find cheap flights to Hong Kong International ...     www.skyscanner.com
# ...

# %%
pd.read_csv("flights_tickets_serp2019-02-01.csv",skiprows=[2,5])
# Out:
#                searchTerms  rank  \
# 0     flights to hong kong     1
# 1     flights to hong kong     3
# 2     flights to hong kong     4
# 3     flights to hong kong     6
# 4     flights to hong kong     7
# ...                    ...   ...
# 3993       tickets to nice     6
# 3994       tickets to nice     7
# 3995       tickets to nice     8
# 3996       tickets to nice     9
# 3997       tickets to nice    10
#
#                                                   title  \
# 0     Cheap Flights to Hong Kong (HKG) from $400 - K...
# 1           Flights to Hong Kong (HKG) | Cathay Pacific
# 2     Cheap Flights to Hong Kong International from ...
# 3     Cheap Flights to Hong Kong - Search Deals on A...
# 4     Travelers on United flight to Hong Kong delaye...
# ...                                                 ...
# 3993                    Billetterie Officielle OGC Nice
# 3994  Cheap flights to Nice from £22 - Book trips to...
# ...

# %%
pd.read_csv("flights_tickets_serp2019-02-01.csv",nrows=45)
# Out:
#              searchTerms  rank  \
# 0   flights to hong kong     1
# 1   flights to hong kong     2
# 2   flights to hong kong     3
# 3   flights to hong kong     4
# 4   flights to hong kong     5
# 5   flights to hong kong     6
# 6   flights to hong kong     7
# 7   flights to hong kong     8
# 8   flights to hong kong     9
# 9   flights to hong kong    10
# 10    flights to bangkok     1
# 11    flights to bangkok     2
# 12    flights to bangkok     3
# 13    flights to bangkok     4
# 14    flights to bangkok     5
# 15    flights to bangkok     6
# 16    flights to bangkok     7
# 17    flights to bangkok     8
# 18    flights to bangkok     9
# 19    flights to bangkok    10
# 20     flights to london     1
# 21     flights to london     2
# 22     flights to london     3
# 23     flights to london     4
# 24     flights to london     5
# 25     flights to london     6
# 26     flights to london     7
# 27     flights to london     8
# 28     flights to london     9
# ...
